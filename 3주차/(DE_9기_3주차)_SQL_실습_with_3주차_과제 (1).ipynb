# %% [markdown]
# Set up Configuration

# %%
# %load_ext sql

# %%
# ID와 PW를 자신의 환경에 맞게 수정
# %sql postgresql://wmfrlek99:*******@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Out:
# 'Connected: wmfrlek99@dev'

# %% [markdown]
# # **이후 아래 SQL에서 "keeyong"을 자신의 스키마로 변경**

# %% [markdown]
# 다양한 SELECT 실행해보기

# %%
# %%sql
#
# SELECT *
# FROM raw_data.user_session_channel
# LIMIT 10;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(1651, '0004289ee1c7b8b08c77e19878106ae3', 'Organic'),
#  (1197, '00053f5e11d1fe4e49a221165b39abc9', 'Facebook'),
#  (1401, '00056c20eb5a029583db75506953f1d9', 'Facebook'),
#  (1399, '00063cb5da1826febf178b669eea3250', 'Facebook'),
#  (1667, '000958fdaefe0dd06f5d7c4e4a5f28d1', 'Instagram'),
#  (468, '000a3f777828d2cdbee98887561aa130', 'Facebook'),
#  (1563, '000cb7efa8a05429dd5309b4bea2eb0c', 'Naver'),
#  (711, '00106ac9184e7d54b570d0f0cb0c38b2', 'Organic'),
#  (473, '0011df6282fe8cf78feeab676fbc3c27', 'Naver'),
#  (420, '00126b47d5502dfb7d01f750ad23d813', 'Facebook')]

# %%
# %%sql
#
# SELECT DISTINCT channel                      -- 유일한 채널 이름을 알고 싶은 경우
# FROM raw_data.user_session_channel;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 6 rows affected.
# [('Organic',),
#  ('Google',),
#  ('Naver',),
#  ('Youtube',),
#  ('Instagram',),
#  ('Facebook',)]

# %%
# %%sql
#
# SELECT COUNT(1)                    -- 테이블의 모든 레코드 수 카운트. COUNT(*). 하나의 레코드
# FROM raw_data.user_session_channel;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(101520,)]

# %% [markdown]
# ### 비어 있는 테이블 만들고 레코드 추가하고 COUNT하기

# %%
# %%sql
#
# DROP TABLE IF EXISTS wmfrlek99.test_table;
# CREATE TABLE wmfrlek99.test_table (
#     value int
# );
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
# %%sql
#
# INSERT INTO wmfrlek99.test_table VALUES (NULL), (1), (1), (0), (0), (4), (3);
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 7 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM wmfrlek99.test_table;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 7 rows affected.
# [(None,), (1,), (1,), (0,), (0,), (4,), (3,)]

# %% [markdown]
# 아래 COUNT 문들의 결과값은 얼마일까?

# %%
# %%sql
#
# SELECT COUNT(1), COUNT(value), COUNT(DISTINCT value)
# FROM wmfrlek99.test_table;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(7, 6, 4)]

# %% [markdown]
# ### Primary Key 이해해보기와 Data Quality 검사해보기

# %%
# %%sql
#
# DROP TABLE IF EXISTS wmfrlek99.test_channel;
# CREATE TABLE wmfrlek99.test_channel (
#    channel varchar(32) primary key,
#    description varchar(64) default 'test'
# );
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
# %%sql
#
# INSERT INTO wmfrlek99.test_channel VALUES ('FACEBOOK', 'test'), ('GOOGLE', 'test');
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 2 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM wmfrlek99.test_channel;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 2 rows affected.
# [('FACEBOOK', 'test'), ('GOOGLE', 'test')]

# %%
# %%sql
#
# INSERT INTO wmfrlek99.test_channel VALUES ('FACEBOOK'), ('GOOGLE');
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 2 rows affected.
# []

# %%
# %%sql
#
# -- 데이터웨어하우스 redshift는 primary key가 적용이 안됨
#
#
# SELECT * FROM wmfrlek99.test_channel;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 4 rows affected.
# [('FACEBOOK', 'test'),
#  ('GOOGLE', 'test'),
#  ('FACEBOOK', 'test'),
#  ('GOOGLE', 'test')]

# %%
# %%sql
#
# SELECT DISTINCT * FROM wmfrlek99.test_channel;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 2 rows affected.
# [('FACEBOOK', 'test'), ('GOOGLE', 'test')]

# %% [markdown]
# 필드 이름 변경해보기

# %%
# %%sql
#
# ALTER TABLE wmfrlek99.test_channel RENAME channel to channelname;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %% [markdown]
# 중복 레코드 확인해보기

# %%
# %%sql
#
# SELECT COUNT(1) FROM wmfrlek99.test_channel;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(4,)]

# %%
# %%sql
#
# SELECT COUNT(1) FROM (
#     SEL
#     ECT DISTINCT * FROM wmfrlek99.test_channel
# );
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# (psycopg2.errors.SyntaxError) syntax error at or near "DISTINCT"
# LINE 3:     ECT DISTINCT * FROM wmfrlek99.test_channel
#                 ^
#
# [SQL: SELECT COUNT(1) FROM (
#     SEL
#     ECT DISTINCT * FROM wmfrlek99.test_channel
# );]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# primary key uniqueness 확인해보기

# %%
# %%sql
#
# SELECT channelname, count(1)
# FROM wmfrlek99.test_channel
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [('FACEBOOK', 2)]

# %% [markdown]
# 타임 스탬프 필드가 있다면 최근에도 업데이트된 레코드가 있는지 꼭 확인. 언제부터 레코드가 생성되었는지도 확인. 월별로 레코드수를 확인해보는 것도 좋은 버릇

# %%
# %%sql
#
# SELECT MAX(ts), MIN(ts)
# FROM raw_data.session_timestamp;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(datetime.datetime(2019, 11, 30, 23, 58, 23), datetime.datetime(2019, 5, 1, 0, 13, 11, 783000))]

# %% [markdown]
# ### CASE WHEN을 사용해보기

# %%
# %%sql
#
# SELECT LEFT(ts, 7), COUNT(1)
# FROM raw_data.session_timestamp
# GROUP BY 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 7 rows affected.
# [('2019-11', 18059),
#  ('2019-08', 17151),
#  ('2019-10', 18899),
#  ('2019-07', 14840),
#  ('2019-09', 15790),
#  ('2019-05', 6261),
#  ('2019-06', 10520)]

# %% [markdown]
# 월별로 10000 혹은 그 이상 세션이면 ">= 10,000" 아니면 "< 10,000" 이렇게 찍어보기

# %%
# %%sql
#
# SELECT LEFT(ts, 7), CASE WHEN COUNT(1) >= 10000 THEN '>= 10,000' ELSE '< 10,000' END
# FROM raw_data.session_timestamp
# GROUP BY 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 7 rows affected.
# [('2019-08', '>= 10,000'),
#  ('2019-11', '>= 10,000'),
#  ('2019-07', '>= 10,000'),
#  ('2019-06', '>= 10,000'),
#  ('2019-09', '>= 10,000'),
#  ('2019-10', '>= 10,000'),
#  ('2019-05', '< 10,000')]

# %% [markdown]
# 월별로 15000 혹은 그 이상 세션이면 ">= 15,000", 10000보다 작으면 "< 10,000", 그 사이이면 "10000 and 15000" 이렇게 찍어보기

# %%
# %%sql
#
# SELECT
#     LEFT(ts, 7),
#     CASE
#         WHEN COUNT(1) >= 15000 THEN '>= 15,000'
#         WHEN COUNT(1) < 10000 THEN '< 10,000'
#         ELSE '10000 and 15000'
#     END
# FROM raw_data.session_timestamp
# GROUP BY 1
# ORDER BY 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 7 rows affected.
# [('2019-05', '< 10,000'),
#  ('2019-06', '10000 and 15000'),
#  ('2019-07', '10000 and 15000'),
#  ('2019-08', '>= 15,000'),
#  ('2019-09', '>= 15,000'),
#  ('2019-10', '>= 15,000'),
#  ('2019-11', '>= 15,000')]

# %% [markdown]
# ### 공백이 들어있는 필드이름 혹은 예약된 키워드를 필드이름으로 사용하려면?

# %%
# %%sql
#
# -- field 이름 사이에 공백이 있으면 안됨, field 안에 group을 사용하지 못함.
#
# DROP TABLE IF EXISTS wmfrlek99.test;
# CREATE TABLE wmfrlek99.test (
#     group int primary key,
#     'mailing address' varchar(32)
# );
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# (psycopg2.errors.SyntaxError) syntax error at or near "group"
# LINE 2:     group int primary key,
#             ^
#
# [SQL: CREATE TABLE wmfrlek99.test (
#     group int primary key,
#     'mailing address' varchar(32)
# );]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %%sql
#
# CREATE TABLE wmfrlek99.test (
#     "group" int primary key,
#     "mail
#     ing address" varchar(32)
# );
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
#
# SELECT "group"
# FROM wmfrlek99.test;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 0 rows affected.
# []

# %% [markdown]
# ### 다양한 WHERE clause 사용해보기

# %% [markdown]
# WHERE에서 "in"을 사용한 clause 사용해보기

# %%
# %%sql
#
# SELECT COUNT(1)
# FROM raw_data.user_session_channel
# WHERE channel in ('Google','Facebook');  -- not in
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(33773,)]

# %%
# %%sql
#
# SELECT COUNT(1)
# FROM raw_data.user_session_channel
# WHERE channel like '%oo%';   -- not like
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(33773,)]

# %%
# %%sql
#
# SELECT COUNT(1)
# FROM raw_data.user_session_channel
# WHERE channel like 'F%';
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(16791,)]

# %%
# %%sql
#
# SELECT COUNT(1)
# FROM raw_data.session_timestamp
# WHERE ts BETWEEN '2019-05-01' and '2019-06-01'; -- a와 b다 포함
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(6261,)]

# %% [markdown]
# ### NULL과 TRUE/FALSE 이해하기

# %%
# %%sql
#
# SELECT *
# FROM wmfrlek99.test_table
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 7 rows affected.
# [(None,), (1,), (1,), (0,), (0,), (4,), (3,)]

# %%
# %%sql
#
# SELECT COUNT(1)
# FROM wmfrlek99.test_table
# WHERE value is NULL; -- primary key로 지정된 필드에 꼭 해보는 것이 좋음. WHERE value != NULL이 아님. IS NULL의 반대는 IS NOT NULL
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(1,)]

# %%
# %%sql
#
# -- NULL을 비교할 때는 =, != 를 사용하는것이 아닌 IS나 ISNULL을 사용해야함
#
# SELECT COUNT(1)
# FROM wmfrlek99.test_table
# WHERE value = NULL;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(0,)]

# %% [markdown]
# 기본적으로 필드는 NULL 값을 가질 수 있음. 만일 어느 필드의 값이 NULL이 될 수 없다면 CREATE TABLE 실행시 지정가능

# %%
# %%sql
#
# DROP TABLE IF EXISTS wmfrlek99.test_null;
# CREATE TABLE wmfrlek99.test_null (
#     value int NOT NULL --속성으로 not null을 지정해줌
# );
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
# %%sql
#
#
# INSERT INTO wmfrlek99.test_null VALUES (NULL);
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# ---------------------------------------------------------------------------
# InternalError_                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1900                     self.dialect.do_execute(
# -> 1901                         cursor, statement, parameters, context
#    1902                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# InternalError_: Cannot insert a NULL value into column value
# DETAIL:
#   -----------------------------------------------
# ...

# %% [markdown]
# Boolean 필터링과 NULL과의 관계

# %%
# %%sql
#
# DROP TABLE IF EXISTS wmfrlek99.test_boolean;
# CREATE TABLE wmfrlek99.test_boolean (
#     value boolean
# )
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# []

# %%
# %%sql
#
# INSERT INTO wmfrlek99.test_boolean VALUES (True), (False), (True), (True), (True), (NULL);
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 6 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM wmfrlek99.test_boolean;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 6 rows affected.
# [(True,), (False,), (True,), (True,), (True,), (None,)]

# %%
# %%sql
#
# SELECT COUNT(1) FROM wmfrlek99.test_boolean WHERE value IS False;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(1,)]

# %%
# %%sql
# -- is False나 is not True나 수학적으로 같아 보일 수 있어도 NULL때문에 반환하는 값이 다름. 주의할 것 !
# SELECT COUNT(1) FROM wmfrlek99.test_boolean WHERE value is not True;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(2,)]

# %% [markdown]
# NULL이 들어간 경우의 연산은?

# %%
# %%sql
#
# SELECT COUNT(NULL);
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(0,)]

# %%
# %%sql
#
# SELECT 1/NULL;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(None,)]

# %%
# %%sql
#
# SELECT 0+NULL;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(None,)]

# %% [markdown]
# ### COALESCE, NULLIF

# %%
# %%sql
#
# SELECT 100/value
# FROM wmfrlek99.test_table;
# --value에 0이 있기 때문에 에러가 생김

# %%
# %%sql
# -- nullif를 통해 값에 0이 있으면 이를 null로 반환하고 나눔
# SELECT value, 100/NULLIF(value, 0)
# FROM wmfrlek99.test_table;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 7 rows affected.
# [(None, None), (1, 100), (1, 100), (0, None), (0, None), (4, 25), (3, 33)]

# %%
# %%sql
#
# SELECT value, COALESCE(value, 1) -- NULL인 경우 1을 대신 사용하고 싶다면
# FROM wmfrlek99.test_table;

# %% [markdown]
# 세션이 가장 많이 생성된 시간대는?

# %%
# %%sql
#
# SELECT EXTRACT(HOUR FROM ts), COUNT(1) as session_count
# FROM raw_data.session_timestamp
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(15, 15339)]

# %% [markdown]
# 가장 많이 사용된 채널은 무엇인가?

# %%
# %%sql
#
# SELECT
#     channel,
#     COUNT(1) AS session_count,
#     COUNT(DISTINCT userId) AS user_count
# FROM raw_data.user_session_channel
# GROUP BY 1                         -- GROUP BY channel
# ORDER BY 2 DESC;              -- ORDER BY session_count DESC
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 6 rows affected.
# [('Youtube', 17091, 889),
#  ('Google', 16982, 893),
#  ('Naver', 16921, 882),
#  ('Organic', 16904, 895),
#  ('Instagram', 16831, 895),
#  ('Facebook', 16791, 889)]

# %% [markdown]
# 가장 많은 세션을 만들어낸 사용자 ID는 무엇인가?

# %%
# %%sql
#
# SELECT
#     userId,
#     COUNT(1) AS count
# FROM raw_data.user_session_channel
# GROUP BY 1                         -- GROUP BY userId
# ORDER BY 2 DESC              -- ORDER BY count DESC
# LIMIT 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(1615, 528)]

# %% [markdown]
# 월별 채널별 유니크한 사용자 수

# %%
# %%sql
#
# SELECT
#   TO_CHAR(A.ts, 'YYYY-MM') AS month,
#   channel,
#   COUNT(DISTINCT B.userid) AS mau
# FROM raw_data.session_timestamp A
# JOIN raw_data.user_session_channel B ON A.sessionid = B.sessionid
# GROUP BY 1, 2
# ORDER BY 1 DESC, 2;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 42 rows affected.
# [('2019-11', 'Facebook', 688),
#  ('2019-11', 'Google', 688),
#  ('2019-11', 'Instagram', 669),
#  ('2019-11', 'Naver', 667),
#  ('2019-11', 'Organic', 677),
#  ('2019-11', 'Youtube', 677),
#  ('2019-10', 'Facebook', 698),
#  ('2019-10', 'Google', 699),
#  ('2019-10', 'Instagram', 707),
#  ('2019-10', 'Naver', 713),
#  ('2019-10', 'Organic', 709),
#  ('2019-10', 'Youtube', 705),
#  ('2019-09', 'Facebook', 597),
#  ('2019-09', 'Google', 599),
#  ('2019-09', 'Instagram', 588),
#  ('2019-09', 'Naver', 592),
#  ('2019-09', 'Organic', 592),
#  ('2019-09', 'Youtube', 588),
#  ('2019-08', 'Facebook', 611),
#  ('2019-08', 'Google', 610),
#  ('2019-08', 'Instagram', 621),
#  ('2019-08', 'Naver', 626),
#  ('2019-08', 'Organic', 608),
#  ('2019-08', 'Youtube', 614),
#  ('2019-07', 'Facebook', 558),
#  ('2019-07', 'Google', 556),
#  ('2019-07', 'Instagram', 567),
# ...

# %% [markdown]
# ### 요약 테이블을 CTAS (Create Table 이름 As SELECT)로 생성해보기

# %%
# %%sql
# --이미 input data에 내가 원하는 정보를 가지고 있을 경우 이를 바탕으로 새로운 테이블을 만들어 내는 경우
# CREATE TABLE wmfrlek99.monthly_active_user_summary AS
# SELECT TO_CHAR(ts, 'YYYY-MM') AS month, COUNT(DISTINCT userid)
# FROM raw_data.user_session_channel A
# JOIN raw_data.session_timestamp B ON A.sessionid = B.sessionid
# GROUP BY 1
# ORDER BY 1 DESC;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
#
# SELECT * FROM wmfrlek99.monthly_active_user_summary;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 7 rows affected.
# [('2019-11', 721),
#  ('2019-08', 662),
#  ('2019-10', 763),
#  ('2019-09', 639),
#  ('2019-07', 623),
#  ('2019-06', 459),
#  ('2019-05', 281)]

# %%
# %%sql
#
# DROP TABLE wmfrlek99.monthly_active_user_summary;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
#
# SELECT EXTRACT(HOUR FROM ts), COUNT(1)
# FROM raw_data.session_timestamp
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(15, 15339)]

# %%
# %%sql
#
# SELECT EXTRACT(DOW FROM ts), COUNT(1)
# FROM raw_data.session_timestamp
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(5, 15091)]

# %%
# %%sql
#
# SELECT EXTRACT(DOW FROM ts), EXTRACT(HOUR FROM ts), COUNT(1)
# FROM raw_data.session_timestamp
# GROUP BY 1, 2
# ORDER BY 3 DESC
# LIMIT 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(5, 15, 2290)]

# %%
# %%sql
#
# SELECT ts, channel
# FROM raw_data.user_session_channel usc
# JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# WHERE userid = 251
# ORDER BY 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 216 rows affected.
# [(datetime.datetime(2019, 5, 1, 12, 18, 26, 637000), 'Facebook'),
#  (datetime.datetime(2019, 5, 2, 13, 6, 12, 47000), 'Instagram'),
#  (datetime.datetime(2019, 5, 3, 13, 43, 21, 857000), 'Instagram'),
#  (datetime.datetime(2019, 5, 4, 13, 54, 0, 610000), 'Instagram'),
#  (datetime.datetime(2019, 5, 5, 13, 30, 8, 260000), 'Google'),
#  (datetime.datetime(2019, 5, 6, 12, 36, 54, 80000), 'Youtube'),
#  (datetime.datetime(2019, 5, 7, 12, 22, 45, 713000), 'Youtube'),
#  (datetime.datetime(2019, 5, 8, 12, 27, 53, 360000), 'Organic'),
#  (datetime.datetime(2019, 5, 9, 11, 54, 21, 527000), 'Youtube'),
#  (datetime.datetime(2019, 5, 10, 14, 29, 36, 197000), 'Facebook'),
#  (datetime.datetime(2019, 5, 11, 12, 42, 13, 727000), 'Facebook'),
#  (datetime.datetime(2019, 5, 12, 12, 46, 57, 153000), 'Youtube'),
#  (datetime.datetime(2019, 5, 13, 11, 56, 26, 650000), 'Google'),
# ...

# %% [markdown]
# ### UNION과 UNION ALL 차이점 이해하기

# %%
# %%sql
# -- 중복된것을 하나만 보여줌
# SELECT 'keeyong' as first_name, 'han' as last_name
#
# UNION
#
# SELECT 'elon', 'musk'
#
# UNION
#
# SELECT 'keeyong', 'han'
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 2 rows affected.
# [('elon', 'musk'), ('keeyong', 'han')]

# %%
# %%sql
# -- 중복된것을 다 return함
# SELECT 'keeyong' as first_name, 'han' as last_name
#
# UNION ALL
#
# SELECT 'elon', 'musk'
#
# UNION ALL
#
# SELECT 'keeyong', 'han'
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 3 rows affected.
# [('keeyong', 'han'), ('elon', 'musk'), ('keeyong', 'han')]

# %% [markdown]
# ## JOIN:
#
# An SQL JOIN clause is used to combine rows from two or more tables, based on a common field between them.
#
# 왼쪽 테이블을 LEFT라고 하고 오른쪽 테이블을 RIGHT이라고 하자. JOIN의 결과는 방식에 상관없이 양쪽의 필드를 모두 가진 새로운 테이블을 만들어내게 됨. 조인의 방식에 따라 다음 두 가지가 달라짐:
#
# 1. 어떤 레코드들이 선택되는지?
# 2. 어떤 필드들이 채워지는지?

# %%
# %%sql
#
# DROP TABLE IF EXISTS wmfrlek99.vital;
# CREATE TABLE wmfrlek99.vital (
#     UserID int,
#     VitalID	int,
#     Date date,
#     Weight int
# );
# INSERT INTO wmfrlek99.vital VALUES
# (100,	1, '2020-01-01', 75),
# (100, 3, '2020-01-02', 78),
# (101, 2, '2020-01-01', 90),
# (101, 4, '2020-01-02', 95);
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# 4 rows affected.
# []

# %%
# %%sql
#
# DROP TABLE IF EXISTS wmfrlek99.alert;
# CREATE TABLE wmfrlek99.alert (
#     AlertID int,
#     VitalID	int,
#     AlertType varchar(32),
#     Date date,
#     UserID int
# );
# INSERT INTO wmfrlek99.alert VALUES
#  (1,	4, 'WeightIncrease', '2020-01-01', 101),
#  (2, NULL, 'MissingVital', '2020-01-04', 100),
#  (3, NULL, 'MissingVital', '2020-01-04', 101);
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# 3 rows affected.
# []

# %% [markdown]
# * INNER JOIN
# 1. 양쪽 테이블에서 매치가 되는 레코드들만 리턴함
# 2. 양쪽 테이블의 필드가 모두 채워진 상태로 리턴됨

# %%
# %%sql
#
# SELECT * FROM wmfrlek99.Vital v
# JOIN wmfrlek99.Alert a ON v.vitalID = a.vitalID;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(101, 4, datetime.date(2020, 1, 2), 95, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101)]

# %% [markdown]
# * LEFT JOIN:
# 1. 왼쪽 테이블의 레코드는 모두 리턴되며 오른쪽 테이블과 매칭이 되는 레코드들의 경우에는 오른쪽 테이블 레코드들의 컬럼들이 채워진 상태로 리턴됨.
# 2. 매칭이 안되는 왼쪽 테이블 레코드들은 오른쪽 테이블에서 들어오는 필드들은 NULL로 채워짐

# %%
# %%sql
#
# SELECT * FROM wmfrlek99.Vital v
# LEFT JOIN wmfrlek99.Alert a ON v.vitalID = a.vitalID;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 4 rows affected.
# [(100, 1, datetime.date(2020, 1, 1), 75, None, None, None, None, None),
#  (100, 3, datetime.date(2020, 1, 2), 78, None, None, None, None, None),
#  (101, 2, datetime.date(2020, 1, 1), 90, None, None, None, None, None),
#  (101, 4, datetime.date(2020, 1, 2), 95, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101)]

# %% [markdown]
# * FULL JOIN (OUTER JOIN):
# 1. 왼쪽 테이블과 오른쪽 테이블의 모든 레코드들을 리턴함
# 2. 매칭되는 경우에만 양쪽 테이블들의 모든 필드들이 채워진 상태로 리턴됨

# %%
# %%sql
#
# SELECT * FROM wmfrlek99.Vital v
# FULL JOIN wmfrlek99.Alert a ON v.vitalID = a.vitalID;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 6 rows affected.
# [(101, 4, datetime.date(2020, 1, 2), 95, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101),
#  (None, None, None, None, 2, None, 'MissingVital', datetime.date(2020, 1, 4), 100),
#  (None, None, None, None, 3, None, 'MissingVital', datetime.date(2020, 1, 4), 101),
#  (101, 2, datetime.date(2020, 1, 1), 90, None, None, None, None, None),
#  (100, 1, datetime.date(2020, 1, 1), 75, None, None, None, None, None),
#  (100, 3, datetime.date(2020, 1, 2), 78, None, None, None, None, None)]

# %% [markdown]
# * CARTESIAN JOIN (CROSS JOIN):
# 1. 조인 조건 없이 두 개 테이블의 내용을 모두 조합한 결과 레코드들을 생성

# %%
# %%sql
#
# SELECT *
# FROM (
#     SELECT vitalid  -- 1,2,3,4
#     FROM wmfrlek99.vital
# )
# CROSS JOIN (
#     SELECT alertid   -- 1,2,3
#     FROM wmfrlek99.alert
# );
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 12 rows affected.
# [(1, 1),
#  (1, 2),
#  (1, 3),
#  (3, 1),
#  (3, 2),
#  (3, 3),
#  (2, 1),
#  (2, 2),
#  (2, 3),
#  (4, 1),
#  (4, 2),
#  (4, 3)]

# %%
# %%sql
#
# SELECT * FROM wmfrlek99.Vital v
# CROSS JOIN wmfrlek99.Alert a;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 12 rows affected.
# [(100, 1, datetime.date(2020, 1, 1), 75, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101),
#  (100, 3, datetime.date(2020, 1, 2), 78, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101),
#  (101, 2, datetime.date(2020, 1, 1), 90, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101),
#  (101, 4, datetime.date(2020, 1, 2), 95, 1, 4, 'WeightIncrease', datetime.date(2020, 1, 1), 101),
#  (100, 1, datetime.date(2020, 1, 1), 75, 2, None, 'MissingVital', datetime.date(2020, 1, 4), 100),
#  (100, 3, datetime.date(2020, 1, 2), 78, 2, None, 'MissingVital', datetime.date(2020, 1, 4), 100),
#  (101, 2, datetime.date(2020, 1, 1), 90, 2, None, 'MissingVital', datetime.date(2020, 1, 4), 100),
#  (101, 4, datetime.date(2020, 1, 2), 95, 2, None, 'MissingVital', datetime.date(2020, 1, 4), 100),
# ...

# %% [markdown]
# * Self-Join

# %%
# %%sql
# -- 같은 테이블을 inner join을 한 결과
# SELECT * FROM wmfrlek99.Vital v1
# JOIN wmfrlek99.Vital v2 ON v1.vitalID = v2.vitalID;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 4 rows affected.
# [(100, 1, datetime.date(2020, 1, 1), 75, 100, 1, datetime.date(2020, 1, 1), 75),
#  (100, 3, datetime.date(2020, 1, 2), 78, 100, 3, datetime.date(2020, 1, 2), 78),
#  (101, 2, datetime.date(2020, 1, 1), 90, 101, 2, datetime.date(2020, 1, 1), 90),
#  (101, 4, datetime.date(2020, 1, 2), 95, 101, 4, datetime.date(2020, 1, 2), 95)]

# %% [markdown]
# Assignment 2: 사용자별로 처음과 마지막 채널
# 알아내기
#
# * 숙제 제출 포맷 (모든 사용자에 대해)
#   * 사용자ID, 첫번째 채널, 마지막 채널
#
# * ROW_NUMBER vs. FIRST_VALUE/LAST_VALUE
# * 사용자 251번의 시간순으로 봤을 때 첫 번째 채널과 마지막 채널은 무엇인가?
#   * 노가다를 하자면 아래 쿼리를 실행해서 처음과 마지막 채널을 보면 된다.
#
#   SELECT ts, channel</br>
#   FROM raw_data.user_session_channel usc</br>
#   JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
#   </br>WHERE userid = 251
#   </br>ORDER BY 1;
#
# * ROW_NUMBER 이용해서 해보자
#   * ROW_NUMBER() OVER (PARTITION BY field1 ORDER BY field2) nn

# %%
# %%sql
#
# WITH cte AS(
#   SELECT userid, channel,(ROW_NUMBER() OVER (Partition BY usc.userid ORDER BY st.ts asc))
#   AS arn, (ROW_NUMBER() OVER (Partition BY usc.userid ORDER BY st.ts desc)) as drn
#   FROM raw_data.user_session_channel usc
#   JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# )
# SELECT cte1.userid, cte1.channel AS first_touch, cte2.channel AS last_touch
# FROM cte cte1
# JOIN cte cte2 ON cte1.userid = cte2.userid
# WHERE cte1.arn = 1 and cte2.drn = 1
# order by 1;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 949 rows affected.
# [(27, 'Youtube', 'Instagram'),
#  (29, 'Naver', 'Naver'),
#  (33, 'Google', 'Youtube'),
#  (34, 'Youtube', 'Naver'),
#  (36, 'Naver', 'Youtube'),
#  (40, 'Youtube', 'Google'),
#  (41, 'Facebook', 'Youtube'),
#  (44, 'Naver', 'Instagram'),
#  (45, 'Youtube', 'Instagram'),
#  (59, 'Instagram', 'Instagram'),
#  (64, 'Youtube', 'Youtube'),
#  (65, 'Youtube', 'Organic'),
#  (68, 'Youtube', 'Organic'),
#  (69, 'Facebook', 'Instagram'),
#  (80, 'Organic', 'Naver'),
#  (84, 'Google', 'Youtube'),
#  (87, 'Youtube', 'Google'),
#  (97, 'Organic', 'Organic'),
#  (112, 'Facebook', 'Youtube'),
#  (113, 'Organic', 'Organic'),
#  (114, 'Instagram', 'Youtube'),
#  (117, 'Organic', 'Youtube'),
#  (163, 'Google', 'Naver'),
#  (173, 'Google', 'Organic'),
#  (181, 'Facebook', 'Instagram'),
#  (184, 'Youtube', 'Youtube'),
#  (187, 'Organic', 'Youtube'),
#  (191, 'Naver', 'Instagram'),
# ...

# %% [markdown]
# Assignment 3
# * Gross Revenue가 가장 큰 UserID 10개 찾기
#   * Gross revenue: Refund 포함한 매출. Refund등의 비용이 빠지면 Net revenue
#   * 반드시 SQL로 해보기

# %%
# %%sql
#
# SELECT userid,sum(amount) AS Gross_revenue,
#         SUM(CASE WHEN refunded is False then amount end ) AS Net_revenue
# FROM raw_data.session_transaction st
# JOIN raw_data.user_session_channel usc ON st.sessionid = usc.sessionid
# group by userid
# order by gross_revenue desc
# limit 10;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(989, 743, 743),
#  (772, 556, 556),
#  (1615, 506, 506),
#  (654, 488, 488),
#  (1651, 463, 463),
#  (973, 438, 438),
#  (262, 422, 422),
#  (1099, 421, 343),
#  (2682, 414, 414),
#  (891, 412, 412)]

# %% [markdown]
# Assignment 4
#
# 채널별 월 매출액 테이블 만들기 (본인 스키마 밑에 CTAS로 테이블 만들기)
#
# 1. session_timestamp, user_session_channel, session_transaction
# 테이블들을 사용
# 2. 아래와 같은 필드로 구성
# * year-month
# * channel
# * uniqueUsers (총방문 사용자)
# * paidUsers (구매 사용자: refund한 경우도 판매로 고려) -> CASE WHEN 사용
# * conversionRate (구매사용자 / 총방문 사용자)
# * Casting이 필요. 분모는 NULLIF로 0으로 나누기 방지 grossRevenue (refund 포함)
# * netRevenue (refund 제외) -> CASE WHEN 사용

# %%
# %%sql
#
# select left(ts,7) as "month", usc.channel,Count(Distinct userid) AS uniqueUsers
# FROM raw_data.user_session_channel as usc
# left join raw_data.session_timestamp as t ON t.sessionid = usc.sessionid
# left join raw_data.session_transaction as st ON st.sessionid = usc.sessionid
# group by 1,2
# order by 1,2;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 42 rows affected.
# [('2019-05', 'Facebook', 247),
#  ('2019-05', 'Google', 253),
#  ('2019-05', 'Instagram', 234),
#  ('2019-05', 'Naver', 237),
#  ('2019-05', 'Organic', 238),
#  ('2019-05', 'Youtube', 244),
#  ('2019-06', 'Facebook', 414),
#  ('2019-06', 'Google', 412),
#  ('2019-06', 'Instagram', 410),
#  ('2019-06', 'Naver', 398),
#  ('2019-06', 'Organic', 416),
#  ('2019-06', 'Youtube', 400),
#  ('2019-07', 'Facebook', 558),
#  ('2019-07', 'Google', 556),
#  ('2019-07', 'Instagram', 567),
#  ('2019-07', 'Naver', 553),
#  ('2019-07', 'Organic', 557),
#  ('2019-07', 'Youtube', 564),
#  ('2019-08', 'Facebook', 611),
#  ('2019-08', 'Google', 610),
#  ('2019-08', 'Instagram', 621),
#  ('2019-08', 'Naver', 626),
#  ('2019-08', 'Organic', 608),
#  ('2019-08', 'Youtube', 614),
#  ('2019-09', 'Facebook', 597),
#  ('2019-09', 'Google', 599),
#  ('2019-09', 'Instagram', 588),
# ...

# %%
# %%sql
#
# SELECT LEFT(ts, 7) "month",
# usc.channel,
# COUNT(DISTINCT userid) uniqueUsers,
# COUNT(DISTINCT (CASE WHEN amount >= 0 THEN userid END)) paidUsers, ROUND(paidUsers::decimal*100/NULLIF(uniqueUsers, 0),2) conversionRate, SUM(amount) grossRevenue,
# SUM(CASE WHEN refunded is not True THEN amount END) netRevenue FROM raw_data.user_session_channel usc
# LEFT JOIN raw_data.session_timestamp t ON t.sessionid = usc.sessionid LEFT JOIN raw_data.session_transaction st ON st.sessionid = usc.sessionid GROUP BY 1, 2
# ORDER BY 1, 2;
# Out:
#  * postgresql://wmfrlek99:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 42 rows affected.
# [('2019-05', 'Facebook', 247, 14, Decimal('5.67'), 1199, 997),
#  ('2019-05', 'Google', 253, 10, Decimal('3.95'), 580, 580),
#  ('2019-05', 'Instagram', 234, 11, Decimal('4.70'), 959, 770),
#  ('2019-05', 'Naver', 237, 11, Decimal('4.64'), 867, 844),
#  ('2019-05', 'Organic', 238, 17, Decimal('7.14'), 1846, 1571),
#  ('2019-05', 'Youtube', 244, 10, Decimal('4.10'), 529, 529),
#  ('2019-06', 'Facebook', 414, 22, Decimal('5.31'), 1578, 1578),
#  ('2019-06', 'Google', 412, 13, Decimal('3.16'), 947, 947),
#  ('2019-06', 'Instagram', 410, 21, Decimal('5.12'), 1462, 1418),
#  ('2019-06', 'Naver', 398, 15, Decimal('3.77'), 1090, 1090),
#  ('2019-06', 'Organic', 416, 14, Decimal('3.37'), 1129, 940),
#  ('2019-06', 'Youtube', 400, 17, Decimal('4.25'), 1042, 1042),
#  ('2019-07', 'Facebook', 558, 32, Decimal('5.73'), 2222, 2144),
# ...
